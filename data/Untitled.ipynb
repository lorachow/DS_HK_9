# %%
import pandas as pd

# %%
df = pd.read_csv('nytimes.csv')

# %%
df.head(3)
# Out:
#    Age  Gender  Impressions  Clicks  Signed_In
# 0   36       0            3       0          1
# 1   73       1            3       0          1
# 2   30       0            3       0          1

# %%
agg_key = 'Age Gender Signed_In'.split()

# %%
dfg = df.groupby(agg_key)

# %%
dfg.sum()
# Out:
#                       Impressions  Clicks
# Age Gender Signed_In
# 0   0      0               685483   19480
# 7   0      1                   20       3
#     1      1                    6       0
# 8   0      1                   19       0
#     1      1                   75       4
# 9   0      1                   91       2
#     1      1                  174       3
# 10  0      1                  167       4
#     1      1                  377      15
# 11  0      1                  457      12
#     1      1                  985      24
# 12  0      1                  951      30
#     1      1                 1912      62
# 13  0      1                 1646      48
#     1      1                 3644     110
# 14  0      1                 2655      70
#     1      1                 5996     160
# 15  0      1                 4220     150
#     1      1                 8660     242
# 16  0      1                 5160     167
#     1      1                12021     355
# ...
