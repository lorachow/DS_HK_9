# %% [markdown]
# # Movies

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np

from plotly.graph_objs import *
from plotly.offline import init_notebook_mode, iplot
import cufflinks as cf

init_notebook_mode()
cf.go_offline()

dims = (980,700)

# %%
df = pd.read_csv('Titles.csv', skiprows=9, encoding='utf-16')

# %% [markdown]
# ### Data Cleaning

# %%
df.sample(5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102389 entries, 0 to 102388
# Data columns (total 12 columns):
# Target               102389 non-null object
# Channel Group ...    102389 non-null object
# Multi Period         102389 non-null int64
# Year                 102389 non-null int64
# Quarter              102389 non-null object
# Month                102389 non-null object
# Date                 102389 non-null object
# Time                 102389 non-null object
# Main Title           102389 non-null object
# All C&S              102389 non-null float64
# Unnamed: 10          0 non-null float64
# Unnamed: 11          0 non-null float64
# dtypes: float64(3), int64(2), object(7)
# memory usage: 9.4+ MB

# %%
# drop empty columns
df = df.iloc[:,:-2]
# clean headers
df.columns = df.columns.str.lower().str.replace(' ','').str.replace('\.\.\.','')

# %%
df.sample(5)
# Out:
#       target        channelgroup  multiperiod  year quarter    month  \
# 72739    A4+  Fox Movies Premium           15  2015  2015q4  2015m11
# 1379     A4+                 HBO           14  2014  2014q2   2014m4
# 68736    A4+  Fox Movies Premium           15  2015  2015q1   2015m1
# 72513    A4+  Fox Movies Premium           15  2015  2015q4  2015m10
# 69900    A4+  Fox Movies Premium           15  2015  2015q2   2015m4
#
#              date      time                 maintitle  allc&s
# 72739  2015-11-06  08:20:00        3 ninjas kick back  0.0000
# 1379   2014-04-09  16:30:00                  I am sam  0.0011
# 68736  2015-01-18  19:10:00  The grand budapest hotel  0.0028
# 72513  2015-10-20  23:10:00                  Whiplash  0.0041
# 69900  2015-04-13  03:45:00     The end of the affair  0.0000

# %%
# Datatypes
df.date = pd.to_datetime(df.date)
# Cleaning up the period columns
df.quarter = df.date.dt.quarter
df.month = df.date.dt.month

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102389 entries, 0 to 102388
# Data columns (total 10 columns):
# target          102389 non-null object
# channelgroup    102389 non-null object
# multiperiod     102389 non-null int64
# year            102389 non-null int64
# quarter         102389 non-null int64
# month           102389 non-null int64
# date            102389 non-null datetime64[ns]
# time            102389 non-null object
# maintitle       102389 non-null object
# allc&s          102389 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(4)
# memory usage: 7.8+ MB

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# Gives you no information cause it's all the same - so could drop it, unless you have a use for it
df.target.value_counts()
# Out:
# A4+    102389
# Name: target, dtype: int64

# %%
# even the graph looks silly :)
df['target'].iplot(kind='histogram', dimensions=dims)
# Out:
# <div id="eeb32a4e-8566-40e6-995f-1e56c0c507fb" style="height: 700; width: 980px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("eeb32a4e-8566-40e6-995f-1e56c0c507fb", [{"opacity": 0.8, "name": "target", "histnorm": "", "histfunc": "count", "marker": {"color": "rgba(255, 153, 51, 1.0)", "line": {"color": "#4D5663", "width": 1.3}}, "x": ["A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+", "A4+",  ...

# %% [markdown]
# ### Let's try and see how the `channelgroup` has done each `year`.

# %%
channels = df.groupby(['channelgroup', 'year'])

# %%
# We've created a clean little dataframe that's going to be useful for plotting
channels[['allc&s']].sum()
# Out:
#                            allc&s
# channelgroup       year
# Fox Action Movies  2014   50.3938
#                    2015   55.2117
#                    2016   18.6200
# Fox Family Movies  2014   72.7969
#                    2015   61.5668
#                    2016   16.4405
# Fox Movies Premium 2014  232.1927
#                    2015   97.4499
#                    2016   39.0427
# HBO                2014  232.2866
#                    2015  149.9917
#                    2016   44.6853
# HBO Family         2014  100.4489
#                    2015   80.9435
#                    2016   21.9236
# HBO HITS           2014  117.9658
#                    2015   92.0839
#                    2016   22.4105
# HBO Signature      2014   48.0736
#                    2015   46.2915
#                    2016   12.4199

# %%
# but really we want it to have channelgroups as rows and year as columns, so we use unstack()
channels['allc&s'].sum().unstack()
# Out:
# year                    2014      2015     2016
# channelgroup
# Fox Action Movies    50.3938   55.2117  18.6200
# Fox Family Movies    72.7969   61.5668  16.4405
# Fox Movies Premium  232.1927   97.4499  39.0427
# HBO                 232.2866  149.9917  44.6853
# HBO Family          100.4489   80.9435  21.9236
# HBO HITS            117.9658   92.0839  22.4105
# HBO Signature        48.0736   46.2915  12.4199

# %%
# You could save the above into a variable, or just chain it up like this when calling iplot()
channels['allc&s'].sum().unstack().iplot(kind='bar', dimensions=dims, barmode='stack')
# Out:
# <div id="b0a9e8e3-21d3-46ef-9991-f81ca62ac90b" style="height: 700; width: 980px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b0a9e8e3-21d3-46ef-9991-f81ca62ac90b", [{"name": 2014, "text": "", "y": [50.39380000000003, 72.79690000000008, 232.19270000000037, 232.28659999999982, 100.44889999999987, 117.96579999999983, 48.07359999999994], "marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "x": ["Fox Action Movies", "Fox Family Movies", "Fox Movies Premium", "HBO", "HBO Family", "HBO HITS", "HBO Signature"], "type": "bar", "orientation": "v"}, {"name": 2015, "text": "", "y": [55.211700000000086, 61.566799999999965, 97.44989999999997, 149.9916999999997, 80.94349999999996, 92.08389999999999, 46.29150000000008], "marker": {"color": "rgba(55, 128, 191, 0.6)", "line": {"color": "rgba(55, 128, 191, 1.0)", "width": 1}}, "x": ["Fox Action Movies", "Fox Family Movies", "Fox Movies Premium", "HBO", "HBO Family", "HBO HITS", "HBO Signature"], "type": "bar", "orientation": "v"}, {"name": 2016, "text": "", "y": [18.62000000000002, 16.440500000000004, 39.04269999999996, 44.68530000000009, 21.92360000000002, 22.410499999999963, 12.419900000000009], "marker": {"color": "rgba(50, 171, 96, 0.6)", "line": {"color": "rgba(50, 171, 96, 1.0)", "width": 1}}, "x": ["Fox Action Movies", "Fox Family Movies", "Fox Movies Premium", "HBO", "HBO Family", "HBO HITS", "HBO Signature"], "type": "bar", "orientation": "v"}], {"barmode": "stack", "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "xaxis1": {"tickfont": {"color": "#4D5663"}, "title": "", "showgrid": true, "zerolinecolor": "#E1E5ED", "gridcolor": "#E1E5ED", "titlefont": {"color": "#4D5663"}}, "height": 700, "yaxis1": {"tickfont": {"color": "#4D5663"}, "title": "", "showgrid": true, "zerolinecolor": "#E1E5ED", "gridcolor": "#E1E5ED", "titlefont": {"color": "#4D5663"}}, "width": 980, "titlefont": {"color": "#4D5663"}, "legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}, "traceorder": "normal"}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %%
# switching the axis is as simple as adding a .T in the mix!
channels['allc&s'].sum().unstack().T.iplot(kind='bar', dimensions=dims, barmode='stack')
# Out:
# <div id="47904c77-707f-41f9-b866-4ed8767990c9" style="height: 700; width: 980px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("47904c77-707f-41f9-b866-4ed8767990c9", [{"name": "Fox Action Movies", "text": "", "y": [50.39380000000003, 55.211700000000086, 18.62000000000002], "marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "x": [2014, 2015, 2016], "type": "bar", "orientation": "v"}, {"name": "Fox Family Movies", "text": "", "y": [72.79690000000008, 61.566799999999965, 16.440500000000004], "marker": {"color": "rgba(55, 128, 191, 0.6)", "line": {"color": "rgba(55, 128, 191, 1.0)", "width": 1}}, "x": [2014, 2015, 2016], "type": "bar", "orientation": "v"}, {"name": "Fox Movies Premium", "text": "", "y": [232.19270000000037, 97.44989999999997, 39.04269999999996], "marker": {"color": "rgba(50, 171, 96, 0.6)", "line": {"color": "rgba(50, 171, 96, 1.0)", "width": 1}}, "x": [2014, 2015, 2016], "type": "bar", "orientation": "v"}, {"name": "HBO", "text": "", "y": [232.28659999999982, 149.9916999999997, 44.68530000000009], "marker": {"color": "rgba(128, 0, 128, 0.6)", "line": {"color": "rgba(128, 0, 128, 1.0)", "width": 1}}, "x": [2014, 2015, 2016], "type": "bar", "orientation": "v"}, {"name": "HBO Family", "text": "", "y": [100.44889999999987, 80.94349999999996, 21.92360000000002], "marker": {"color": "rgba(219, 64, 82, 0.6)", "line": {"color": "rgba(219, 64, 82, 1.0)", "width": 1}}, "x": [2014, 2015, 2016], "type": "bar", "orientation": "v"}, {"name": "HBO HITS", "text": "", "y": [117.96579999999983, 92.08389999999999, 22.410499999999963], "marker": {"color": "rgba(0, 128, 128, 0.6)", "line": {"color": "rgba(0, 128, 128, 1.0)", "width": 1}}, "x": [2014, 2015, 2016], "type": "bar", "orientation": "v"}, {"name": "HBO Signature", "text": "", "y": [48.07359999999994, 46.29150000000008, 12.419900000000009], "marker": {"color": "rgba(255, 255, 51, 0.6)", "line": {"color": "rgba(255, 255, 51, 1.0)", "width": 1}}, "x": [2014, 2015, 2016], "type": "bar", "orientation": "v"}], {"barmode": "stack", "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "xaxis1": {"tickfont": {"color": "#4D5663"}, "title": "", "showgrid": true, "zerolinecolor": "#E1E5ED", "gridcolor": "#E1E5ED", "titlefont": {"color": "#4D5663"}}, "height": 700, "yaxis1": {"tickfont": {"color": "#4D5663"}, "title": "", "showgrid": true, "zerolinecolor": "#E1E5ED", "gridcolor": "#E1E5ED", "titlefont": {"color": "#4D5663"}}, "width": 980, "titlefont": {"color": "#4D5663"}, "legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}, "traceorder": "normal"}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# This is just the beginning! Good luck :)
